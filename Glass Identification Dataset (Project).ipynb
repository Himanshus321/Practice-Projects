# %%
#import necessary library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Import data set from Git Hub Raw file and checking shape of the data set.
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv')
df.shape
# Out:
# (213, 11)

# %%
# Checking top 5 rows of data set.

df.head()
# Out:
#    1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0  2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1  3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2  4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3  5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4  6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1

# %%
df.columns
# Out:
# Index(['1', '1.52101', '13.64', '4.49', '1.10', '71.78', '0.06', '8.75',
#        '0.00', '0.00.1', '1.1'],
#       dtype='object')

# %%
# rename the columns name as per given project statements.

df.columns=['Id number','RI','Na','Mg','Al','Si','K','Ca','Ba','Fe','Type of Glass']

# %%
# Checking top 5 rows again after remaning the column name.
df.head()
# Out:
#    Id number       RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  \
# 0          2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00
# 1          3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00
# 2          4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00
# 3          5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00
# 4          6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26
#
#    Type of Glass
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# Id number is only nominal data so we are deleting the same.
df=df.drop(['Id number'],axis=1)
df.head() # Checking again for confirming the same.
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba    Fe  Type of Glass
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.00              1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.00              1
# 2  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.00              1
# 3  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.00              1
# 4  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.0  0.26              1

# %%
# Checking dataset info.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RI             213 non-null    float64
#  1   Na             213 non-null    float64
#  2   Mg             213 non-null    float64
#  3   Al             213 non-null    float64
#  4   Si             213 non-null    float64
#  5   K              213 non-null    float64
#  6   Ca             213 non-null    float64
#  7   Ba             213 non-null    float64
#  8   Fe             213 non-null    float64
#  9   Type of Glass  213 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
# all our features having float data type and continous.
# Target variable in int and Categorical in nature.

# %%
# Checking nullvalues in this data set.
df.isnull().sum()
# Out:
# RI               0
# Na               0
# Mg               0
# Al               0
# Si               0
# K                0
# Ca               0
# Ba               0
# Fe               0
# Type of Glass    0
# dtype: int64

# %%
# thers is no any null value in this data set.

# %%
# Checking counts of our target variable in this data set.
plt.figure(figsize=(10,8))
sns.countplot(x='Type of Glass',data=df)
plt.title('Type of Glass in Data Set')
plt.show()

# %%
# Checking stats of dataset.
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean     1.518353   13.406761    2.676056    1.446526   72.655023    0.499108
# std      0.003039    0.818371    1.440453    0.499882    0.774052    0.653035
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516520   12.900000    2.090000    1.190000   72.280000    0.130000
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.560000
# 75%      1.519150   13.830000    3.600000    1.630000   73.090000    0.610000
# max      1.533930   17.380000    3.980000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe  Type of Glass
# count  213.000000  213.000000  213.000000     213.000000
# mean     8.957934    0.175869    0.057277       2.788732
# std      1.426435    0.498245    0.097589       2.105130
# ...

# %% [markdown]
# 1. Looking abnormility in K, Ba and Fe as mean is lower than std.
# 2. Looking difference in 75% and max of K and Ca column.
# 3. Mg, K, Ba and Fe are zero which is looking abnormal.

# %%
# Standardize the data
import scipy.stats as stats
from scipy.stats import zscore

# %%
df.shape
# Out:
# (213, 10)

# %%
# by z-score method

threshold=3
z=np.abs(zscore(df))
np.where(z>3)

df=df[(z<3).all(axis=1)]
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type of Glass
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00              1
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00              1
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00              1
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00              1
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26              1
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...            ...
# 207  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.00              7
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00              7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00              7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00              7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00              7
#
# [193 rows x 10 columns]

# %%
df.skew()
# Out:
# RI               0.971729
# Na               0.375857
# Mg              -1.533664
# Al               0.649917
# Si              -0.436288
# K                0.297900
# Ca               1.074092
# Ba               3.178256
# Fe               1.478611
# Type of Glass    1.277279
# dtype: float64

# %%
# showing skewness in Fe, Ba, Ca, and Mg. wil check distplot also.

# %%
plt.figure(figsize=(15,10),facecolor='red')
plotnumber=1

for column in df:
    if plotnumber<=10:
        ax=plt.subplot(2,5,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=10)
    
    plotnumber+=1
    
plt.show()

# %%
# from above plot showing that.
# data is skewed in Fe, K, Ba,Ca

# %%
fig, ax = plt.subplots (ncols=5, nrows=2, figsize=(15,10))
index = 0
ax = ax.flatten()
for col, value in df.items():
    sns.boxplot(y=col, data=df, ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)
plt.show()

# %%
df.head(2)
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type of Glass
# 0  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0              1
# 1  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0              1

# %%
# seperating the data set into two parts. Features and Label.

x=df.drop(['Type of Glass'],axis=1)
y=df['Type of Glass']

# %%
# Checking the relationship between features and label.
plt.figure(figsize=(15,10))
plotnumber=1

for column in x:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.stripplot(y,x[column])
    plotnumber+=1
    
plt.show()

# %%
# I can see all the features are contributing to predict type of glass.

# %% [markdown]
# # Machine Learning Model for Classification and Evaluation Metrics

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Train Test Split

# %%
x=df.drop(['Type of Glass'],axis=1)
y=df['Type of Glass']

# %%
x # diplaying all the features.
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...
# 207  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.00
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00
#
# [193 rows x 9 columns]

# %% [markdown]
# # Standardization of Features

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0   -0.191475  0.704498  0.558738 -0.145324  0.007760  0.165576 -1.005952
# 1   -0.819092  0.169658  0.520382  0.260836  0.455342 -0.154697 -1.056501
# 2   -0.169531 -0.305754  0.627781 -0.303276 -0.198816  0.485849 -0.611669
# 3   -0.274865 -0.216615  0.574081 -0.416098  0.610275  0.414677 -0.763316
# 4   -0.915648 -0.929734  0.566410  0.441351  0.420913  0.734950 -0.763316
# ..        ...       ...       ...       ...       ...       ...       ...
# 188 -0.722535  1.417617 -2.202957  2.968571  0.214336 -1.542547  0.631836
# 189 -0.797147  1.075914 -2.202957  3.284473 -0.198816 -1.257860  0.358872
# 190 -0.525034  2.234732 -2.202957  1.276236  0.575845 -1.542547 -0.429693
# 191  1.142758  1.402760 -2.202957  1.343930  1.195574 -1.542547 -0.389254
# 192 -0.674257  1.432473 -2.202957  1.163414  1.522654 -1.542547 -0.348814
#
#            Ba        Fe
# 0   -0.347296 -0.605187
# 1   -0.347296 -0.605187
# ...

# %% [markdown]
# # Creating the training and testing data sets

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=213)
# I am taking 25 percent of the complete dataset for training purpose and the remaing 75 percent with be used to train the machine learning models

# %%
# Classification Model Function

def classify(model, x, y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=213)
    
    # Training the model
    model.fit(x_train, y_train)
    
    # Predicting y_test
    pred = model.predict(x_test)
    
    # Accuracy Score
    acc_score = (accuracy_score(y_test, pred))
    print("Accuracy Score:", acc_score)
    
    # Classification Report
    class_report = classification_report(y_test, pred)
    print("\nClassification Report:\n", class_report)
    
    # Cross Validation Score
    cv_score = (cross_val_score(model, x, y, cv=5).mean())
    print("Cross Validation Score:", cv_score)
    
    # Result of accuracy minus cv scores
    result = acc_score - cv_score
    print("\nAccuracy Score - Cross Validation Score is", result)

# %% [markdown]
# I have defined a class that will perform the train-test split, training of model, predicting the label value, getting the accuracy score, generating the classification report, getting the cross validation score and the result of difference between the accuracy score and cross validation score.

# %%
model=LogisticRegression()
classify(model,x,y)
# Out:
# Accuracy Score: 0.6530612244897959
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.52      0.93      0.67        15
#            2       0.90      0.39      0.55        23
#            3       0.00      0.00      0.00         2
#            5       1.00      1.00      1.00         2
#            6       0.33      1.00      0.50         1
#            7       1.00      1.00      1.00         6
#
#     accuracy                           0.65        49
#    macro avg       0.63      0.72      0.62        49
# weighted avg       0.75      0.65      0.63        49
#
# Cross Validation Score: 0.6475033738191632
#
# Accuracy Score - Cross Validation Score is 0.005557850670632636

# %%
#Support Vector Classifier

from sklearn.svm import SVC

# %%
model=SVC(C=1.0, kernel='rbf', gamma='auto', random_state=42)
classify(model, x, y)
# Out:
# Accuracy Score: 0.7755102040816326
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.62      1.00      0.77        15
#            2       0.89      0.70      0.78        23
#            3       0.00      0.00      0.00         2
#            5       1.00      1.00      1.00         2
#            6       0.00      0.00      0.00         1
#            7       1.00      0.83      0.91         6
#
#     accuracy                           0.78        49
#    macro avg       0.59      0.59      0.58        49
# weighted avg       0.77      0.78      0.75        49
#
# Cross Validation Score: 0.6893387314439945
#
# Accuracy Score - Cross Validation Score is 0.08617147263763814

# %%
# Decision Tree Classifier

model=DecisionTreeClassifier(random_state=21, max_depth=15)
classify(model, x, y)
# Out:
# Accuracy Score: 0.5714285714285714
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.57      0.53      0.55        15
#            2       0.68      0.65      0.67        23
#            3       0.00      0.00      0.00         2
#            5       1.00      0.50      0.67         2
#            6       0.00      0.00      0.00         1
#            7       1.00      0.67      0.80         6
#
#     accuracy                           0.57        49
#    macro avg       0.54      0.39      0.45        49
# weighted avg       0.66      0.57      0.61        49
#
# Cross Validation Score: 0.6004048582995951
#
# Accuracy Score - Cross Validation Score is -0.028976286871023715

# %%
# K Neighbors Classifier
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=15)
classify(model, x, y)
# Out:
# Accuracy Score: 0.673469387755102
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.54      1.00      0.70        15
#            2       0.92      0.48      0.63        23
#            3       0.00      0.00      0.00         2
#            5       1.00      0.50      0.67         2
#            6       0.33      1.00      0.50         1
#            7       1.00      0.83      0.91         6
#
#     accuracy                           0.67        49
#    macro avg       0.63      0.64      0.57        49
# weighted avg       0.76      0.67      0.66        49
#
# Cross Validation Score: 0.6013495276653172
#
# Accuracy Score - Cross Validation Score is 0.07211986008978477

# %%
svc_param = {'kernel' : ['poly', 'sigmoid', 'rbf'],
             'gamma' : ['scale', 'auto'],
             'shrinking' : [True, False],
             'random_state' : [21,42,104],
             'probability' : [True, False],
             'decision_function_shape' : ['ovo', 'ovr'],
             'verbose' : [True, False]}

# %%
GSCV = GridSearchCV(SVC(), svc_param, cv=5)
GSCV.fit(x_train,y_train)
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSV
# ...

# %%
GSCV.best_params_
# Out:
# {'decision_function_shape': 'ovo',
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'probability': True,
#  'random_state': 21,
#  'shrinking': True,
#  'verbose': True}

# %%
Final_Model = SVC(decision_function_shape='ovo', gamma='scale', kernel='rbf', probability=True, random_state=21,
                 shrinking=True, verbose=True)
Classifier = Final_Model.fit(x_train, y_train)
fmod_pred = Final_Model.predict(x_test)
fmod_acc = (accuracy_score(y_test, fmod_pred))*100
print("Accuracy score for the Best Model is:", fmod_acc)
# Out:
# [LibSVM]Accuracy score for the Best Model is: 75.51020408163265
